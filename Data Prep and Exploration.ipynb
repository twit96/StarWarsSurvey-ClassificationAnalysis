# %% [markdown]
# # Data Analysis of Austin 311 Public Dataset

# %% [markdown]
# Chance Mason, Nicolas Arrieche Villegas, Mitchell Walker, Tyler Wittig

# %% [markdown]
# ### Project Description

# %% [markdown]
# The Austin TX 311 Public Dataset gives the date, time, location, and type of non-emergency complaints filed in Austin. It contains 888,667 records, each with 20 features - such as time request was made, street address, and latitude/longitude.
#
# Data collected from CSR production system.
# Data begins 01/03/2014 and is refreshed daily at 4:00am.
# (Note: CSR (Corporate social responsibility) is a type of international private business self-regulation that aims to contribute to societal goals of a philanthropic, activist, or charitable nature or by engage in or support volunteering or ethically-oriented practices.)
#
# The dataset can be found [here](https://data.austintexas.gov/Utilities-and-City-Services/Austin-311-Public-Data/xwdj-i9he).
#
# Our aim is to analyze this dataset to predict the type of complaint issued by a person given the time and location of the complaint.

# %% [markdown]
# # Data Cleaning and Exploration

# %%
import pandas as pd
# Enable inline mode for matplotlib so that Jupyter displays graphs
# %matplotlib inline
pd.__version__ # version of pandas being using
# Out:
# '1.0.0'

# %%
# Read in the dataset
data = pd.read_csv("Austin_311_Public_Data.csv")
data.head()
# Out:
#   Service Request (SR) Number                       SR Description  \
# 0                 19-00422824                Injured / Sick Animal
# 1                 19-00422828  Animal Control - Assistance Request
# 2                 18-00407565  Animal Control - Assistance Request
# 3                 19-00308199                   Obstruction in ROW
# 4                 19-00472597   Austin Code - Request Code Officer
#
#   Method Received SR Status      Status Change Date            Created Date  \
# 0           Phone    Closed  11/03/2019 02:10:35 PM  11/03/2019 01:54:07 PM
# 1           Phone    Closed  11/03/2019 02:40:35 PM  11/03/2019 01:59:18 PM
# 2           Phone    Closed  12/21/2019 10:56:38 AM  11/29/2018 12:48:09 PM
# 3           Phone  Resolved  12/17/2019 11:02:41 AM  08/13/2019 10:24:30 AM
# 4           Phone    Closed  12/13/2019 03:52:44 PM  12/13/2019 03:44:17 PM
#
#          Last Update Date              Close Date  \
# 0  11/03/2019 02:10:35 PM  11/03/2019 02:10:35 PM
# ...
